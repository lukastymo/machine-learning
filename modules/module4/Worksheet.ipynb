# %%
from sklearn.datasets.samples_generator import make_blobs

X, y = make_blobs(n_samples=10, centers=3, n_features=2, random_state=0)

# %%
X.shape
# Out:
# (10, 2)

# %%
y
# Out:
# array([0, 0, 1, 0, 2, 2, 2, 1, 1, 0])

# %%
X
# Out:
# array([[ 1.12031365,  5.75806083],
#        [ 1.7373078 ,  4.42546234],
#        [ 2.36833522,  0.04356792],
#        [ 0.87305123,  4.71438583],
#        [-0.66246781,  2.17571724],
#        [ 0.74285061,  1.46351659],
#        [-4.07989383,  3.57150086],
#        [ 3.54934659,  0.6925054 ],
#        [ 2.49913075,  1.23133799],
#        [ 1.9263585 ,  4.15243012]])

# %%
max([1, 2, 3])
# Out:
# 3

# %%
def featureScaling(arr):
    arr_min = min(arr)
    arr_max = max(arr)
    return list(map(lambda x: (x-arr_min)/(arr_max-arr_min), arr))

featureScaling([0, 1, 2, 3, 4])
# Out:
# [0.0, 0.25, 0.5, 0.75, 1.0]

# %%
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
# %matplotlib inline

df = pd.DataFrame(np.random.randn(1000, 4), columns=['A', 'B', 'C', 'D'])
scatter_matrix(df, alpha=0.2, figsize = (14,8), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x111afe978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111b62da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111b95470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111bbeb00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x111bf01d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111bf0208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111c3cef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111c6d5c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x111c93c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111cc4320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111ced9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111d1f080>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x111d46710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111d6dda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111d9e470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x111dc5b00>]],
#       dtype=object)

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['A','B','C','D'])
scatter_matrix(df, alpha=0.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113bae898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cc03c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cc33320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11434c9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11437e080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11437e0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1143d0da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1143ff438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x114427ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11445a198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11447f828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1144a7eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1144d8588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1144fec18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1145302e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114558978>]],
#       dtype=object)
