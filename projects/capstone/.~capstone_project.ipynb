# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

import numpy as np
import pandas as pd
import statsmodels.api as sm
from scipy import stats
from sklearn.metrics import mean_squared_error
from math import sqrt
from random import randint
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras.layers import Dropout
from keras.layers import Activation, Dense
from keras.callbacks import EarlyStopping
from keras import initializers
from matplotlib import pyplot
from datetime import datetime
from matplotlib import pyplot as plt

# %%
from datetime import datetime

def toDate(ts):
    return datetime.fromtimestamp(float(ts)).date()

np.random.seed(7)

# %% [markdown]
# # Load the data

# %%
rawData = pd.read_csv("~/data/bitcoin-historical-data/coinbaseUSD_1-min_data_2014-12-01_to_2018-06-27.csv", parse_dates=True, date_parser=toDate, index_col="Timestamp")

# %% [markdown]
# ## Check data quality

# %%
# Count nulls
for col in rawData.columns:
    print(rawData[col].isna().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
df = rawData
df.index.names = ["Date"]
df['Volume'] = pd.to_numeric(df['Volume_(Currency)'])

df.shape
df
# Out:
#                Open     High      Low    Close  Volume_(BTC)  \
# Date
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# 2014-12-01   300.00   300.00   300.00   300.00      0.010000
# ...             ...      ...      ...      ...           ...
# 2018-06-27  6138.05  6138.05  6131.00  6131.00      3.912121
# 2018-06-27  6131.01  6131.01  6120.84  6120.84     38.624883
# 2018-06-27  6120.83  6120.83  6119.13  6119.13     26.353725
# 2018-06-27  6119.13  6119.14  6105.52  6105.52     18.117768
# 2018-06-27  6105.52  6107.02  6100.35  6100.35     22.443270
# 2018-06-27  6100.01  6104.19  6092.11  6103.48     12.532631
# 2018-06-27  6103.47  6119.13  6095.11  6109.01     18.790399
# 2018-06-27  6109.02  6109.02  6100.00  6100.01      7.631874
# 2018-06-27  6100.00  6100.01  6096.19  6096.19      7.210643
# 2018-06-27  6095.35  6111.67  6095.35  6111.67      4.117127
# 2018-06-27  6111.66  6111.67  6107.53  6109.99      3.666525
# 2018-06-27  6109.99  6110.00  6101.48  6103.70      3.929562
# 2018-06-27  6103.56  6103.57  6089.04  6097.05     32.778777
# 2018-06-27  6103.32  6103.58  6103.32  6103.58      2.420030
# 2018-06-27  6103.58  6103.58  6091.00  6099.46      4.066706
# 2018-06-27  6099.47  6099.47  6006.39  6049.54    328.442812
# 2018-06-27  6049.54  6068.25  6048.00  6068.24     96.390870
# 2018-06-27  6068.25  6079.99  6066.81  6066.81     14.085675
# 2018-06-27  6066.09  6066.10  6048.00  6048.01     16.698673
# 2018-06-27  6051.01  6065.99  6051.01  6059.99      8.968766
# 2018-06-27  6060.00  6065.99  6059.99  6065.99      7.226659
# 2018-06-27  6065.99  6079.06  6065.98  6078.06     29.526121
# 2018-06-27  6078.06  6078.06  6060.00  6065.98     17.584980
# 2018-06-27  6065.98  6070.15  6065.00  6065.00      1.244344
# 2018-06-27  6065.00  6070.16  6060.01  6064.02      2.516637
# 2018-06-27  6064.03  6080.00  6064.03  6080.00     10.561973
# 2018-06-27  6080.00  6080.00  6071.52  6077.99      0.682001
# 2018-06-27  6078.00  6081.00  6077.99  6081.00      5.710185
# 2018-06-27  6081.00  6085.70  6074.00  6074.00     20.892658
# 2018-06-27  6074.01  6074.01  6071.52  6071.53     33.898112
#
#             Volume_(Currency)  Weighted_Price        Volume
# Date
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# 2014-12-01       3.000000e+00      300.000000  3.000000e+00
# ...                       ...             ...           ...
# 2018-06-27       2.399707e+04     6134.030831  2.399707e+04
# 2018-06-27       2.367755e+05     6130.128486  2.367755e+05
# 2018-06-27       1.612907e+05     6120.222838  1.612907e+05
# 2018-06-27       1.108240e+05     6116.866147  1.108240e+05
# 2018-06-27       1.369749e+05     6103.161193  1.369749e+05
# 2018-06-27       7.639967e+04     6096.059759  7.639967e+04
# 2018-06-27       1.148144e+05     6110.269641  1.148144e+05
# 2018-06-27       4.658682e+04     6104.244173  4.658682e+04
# 2018-06-27       4.398471e+04     6099.970525  4.398471e+04
# 2018-06-27       2.512208e+04     6101.846787  2.512208e+04
# 2018-06-27       2.240357e+04     6110.300305  2.240357e+04
# 2018-06-27       2.399803e+04     6107.050568  2.399803e+04
# 2018-06-27       1.997259e+05     6093.147650  1.997259e+05
# 2018-06-27       1.477083e+04     6103.571977  1.477083e+04
# 2018-06-27       2.479840e+04     6097.908276  2.479840e+04
# 2018-06-27       1.987433e+06     6051.078196  1.987433e+06
# 2018-06-27       5.837419e+05     6055.987154  5.837419e+05
# 2018-06-27       8.555354e+04     6073.797829  8.555354e+04
# 2018-06-27       1.011007e+05     6054.412458  1.011007e+05
# 2018-06-27       5.431224e+04     6055.709674  5.431224e+04
# 2018-06-27       4.380306e+04     6061.315276  4.380306e+04
# 2018-06-27       1.791363e+05     6067.046199  1.791363e+05
# 2018-06-27       1.067265e+05     6069.185637  1.067265e+05
# 2018-06-27       7.550332e+03     6067.721299  7.550332e+03
# 2018-06-27       1.526347e+04     6065.027431  1.526347e+04
# 2018-06-27       6.414883e+04     6073.564990  6.414883e+04
# 2018-06-27       4.145298e+03     6078.136687  4.145298e+03
# 2018-06-27       3.470863e+04     6078.372515  3.470863e+04
# 2018-06-27       1.270504e+05     6081.105271  1.270504e+05
# 2018-06-27       2.058961e+05     6073.969960  2.058961e+05
#
# [1819074 rows x 8 columns]

# %%
# Do we have all days?
expected_dates = pd.period_range(min(df.index.values), max(df.index.values))

# %%
i = 0
j = 0

A = df.index.values
B = expected_dates

while (i < A.shape[0] and j < B.shape[0]):
    date1 = pd.to_datetime(A[i]).date()
    date2 = B[j].to_timestamp().date()
    if (date1 == date2):
        i += 1
        j += 1
    elif (date1 < date2):
        i += 1
    else:
        print("Missing " + str(date1) + " " + str(date2))
        j += 1
# Out:
# Missing 2014-12-06 2014-12-05
# Missing 2014-12-08 2014-12-07
# Missing 2014-12-10 2014-12-09
# Missing 2014-12-12 2014-12-11
# Missing 2014-12-18 2014-12-13
# Missing 2014-12-18 2014-12-14
# Missing 2014-12-18 2014-12-15
# Missing 2014-12-18 2014-12-16
# Missing 2014-12-18 2014-12-17
# Missing 2015-01-08 2014-12-19
# Missing 2015-01-08 2014-12-20
# Missing 2015-01-08 2014-12-21
# Missing 2015-01-08 2014-12-22
# Missing 2015-01-08 2014-12-23
# Missing 2015-01-08 2014-12-24
# Missing 2015-01-08 2014-12-25
# Missing 2015-01-08 2014-12-26
# Missing 2015-01-08 2014-12-27
# Missing 2015-01-08 2014-12-28
# Missing 2015-01-08 2014-12-29
# Missing 2015-01-08 2014-12-30
# Missing 2015-01-08 2014-12-31
# Missing 2015-01-08 2015-01-01
# Missing 2015-01-08 2015-01-02
# Missing 2015-01-08 2015-01-03
# Missing 2015-01-08 2015-01-04
# Missing 2015-01-08 2015-01-05
# Missing 2015-01-08 2015-01-06
# Missing 2015-01-08 2015-01-07
# Missing 2015-01-13 2015-01-09
# Missing 2015-01-13 2015-01-10
# Missing 2015-01-13 2015-01-11
# Missing 2015-01-13 2015-01-12
# Missing 2015-01-19 2015-01-18

# %%
df["Close"].max(axis = 0)
# Out:
# 19891.99

# %% [markdown]
# # Preprocess the data

# %%
historical_prices = df.resample('1D').agg({'Open': 'first', 
                                 'High': 'max', 
                                 'Low': 'min', 
                                 'Close': 'last',
                                 'Volume': 'sum'}).dropna()
historical_prices = historical_prices[['Close', 'Volume']]

number_of_days = historical_prices.shape[0]
historical_prices.shape
# Out:
# (1271, 2)

# %%
historical_prices.reset_index().plot(x="Date", y="Close", figsize=(8, 6), label="BTC to USD")

# %%
historical_prices.reset_index().plot(x="Date", y="Volume", figsize=(8, 6), label="BTC to USD")

# %% [markdown]
# # Split the dataset into training and testing set

# %%
test_split_point = int(number_of_days * 0.8)
train = historical_prices[:test_split_point] # 80% of the days are the train set 
test = historical_prices[test_split_point:] # 20% of the days are the test set

# %%
train.shape
# Out:
# (1016, 2)

# %%
test.shape
# Out:
# (255, 2)

# %% [markdown]
# # Prepare training and testing model

# %%
def normalize(dataset, window_len):
    return (dataset['Close'][window_len:].values/dataset['Close'][:-window_len].values)-1
    
def reverseNormalize(normalized, original, window_len):
    return (normalized + 1) * original[:-window_len]

def prepareInputAndOutput(dataset, window_len, norm_cols):
    inputs = []
    for i in range(len(dataset)-window_len):
        temp_set = dataset[i:(i+window_len)].copy()
        for col in norm_cols:
            temp_set.loc[:, col] = temp_set[col]/temp_set[col].iloc[0] - 1    
        inputs.append(temp_set)
        
    inputs = [np.array(inputs) for inputs in inputs]
    inputs = np.array(inputs)
    
    outputs = normalize(dataset, window_len)

    return (inputs, outputs)

# %% [markdown]
# # Choose (hyper) parameters

# %%
window_len = 10
norm_cols = ["Close", "Volume"]
batch_size = 2
epochs = 50
units = 64 # Dimensionality

# %% [markdown]
# # Train model

# %%
LSTM_training_inputs, LSTM_training_outputs = prepareInputAndOutput(train, window_len, norm_cols)

# %%
model = Sequential()

model.add(LSTM(units,
               input_shape=(LSTM_training_inputs.shape[1], LSTM_training_inputs.shape[2]),
               return_sequences=False))
model.add(Dropout(0.2))
# model.add(LSTM(units,
#                stateful=True,
#                return_sequences=False))
# model.add(Dropout(0.2))
model.add(Dense(units=1))
model.add(Activation("linear"))

model.compile(loss="mae", optimizer="adam")

model.summary()

# %%
model.fit(LSTM_training_inputs,
          LSTM_training_outputs,
          epochs=epochs, 
          batch_size=batch_size, 
          verbose=2, 
          validation_split=0.1)
# Out:
# Train on 905 samples, validate on 101 samples
# Epoch 1/50
#  - 13s - loss: 0.0543 - val_loss: 0.0635
# Epoch 2/50
#  - 7s - loss: 0.0397 - val_loss: 0.0537
# Epoch 3/50
#  - 7s - loss: 0.0334 - val_loss: 0.0458
# Epoch 4/50
#  - 8s - loss: 0.0312 - val_loss: 0.0442
# Epoch 5/50
#  - 8s - loss: 0.0311 - val_loss: 0.0428
# Epoch 6/50
#  - 8s - loss: 0.0304 - val_loss: 0.0410
# Epoch 7/50
#  - 8s - loss: 0.0295 - val_loss: 0.0436
# Epoch 8/50
#  - 8s - loss: 0.0281 - val_loss: 0.0416
# Epoch 9/50
#  - 9s - loss: 0.0297 - val_loss: 0.0403
# Epoch 10/50
#  - 8s - loss: 0.0271 - val_loss: 0.0398
# Epoch 11/50
#  - 8s - loss: 0.0288 - val_loss: 0.0398
# Epoch 12/50
#  - 8s - loss: 0.0271 - val_loss: 0.0390
# Epoch 13/50
#  - 7s - loss: 0.0298 - val_loss: 0.0404
# Epoch 14/50
#  - 7s - loss: 0.0268 - val_loss: 0.0408
# Epoch 15/50
#  - 7s - loss: 0.0279 - val_loss: 0.0418
# Epoch 16/50
#  - 7s - loss: 0.0284 - val_loss: 0.0387
# Epoch 17/50
#  - 7s - loss: 0.0263 - val_loss: 0.0398
# Epoch 18/50
#  - 7s - loss: 0.0259 - val_loss: 0.0394
# Epoch 19/50
#  - 7s - loss: 0.0259 - val_loss: 0.0400
# Epoch 20/50

# %% [markdown]
# # Test model for unseen data

# %% [markdown]
# This test checks how good is the model in predicting future prices for the unseen historical data. If RMSE is small, the prediction is good

# %%
LSTM_test_inputs, LSTM_test_outputs = prepareInputAndOutput(test, window_len, norm_cols)

# %%
predicted_values = model.predict(LSTM_test_inputs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1134-f583d4d4f6e8> in <module>
# ----> 1 predicted_values = model.predict(LSTM_test_inputs)
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1155                                  'divided by the batch size. Found: ' +
#    1156                                  str(x[0].shape[0]) + ' samples. '
# -> 1157                                  'Batch size: ' + str(batch_size) + '.')
#    1158
#    1159         # Prepare inputs, delegate logic to `predict_loop`.
#
# ValueError: In a stateful network, you should only pass inputs with a number of samples that can be divided by the batch size. Found: 245 samples. Batch size: 32.

# %%
predicted = (np.transpose(predicted_values))

# %%
actual = LSTM_test_outputs

# %% [markdown]
# # Plot normalized data

# %%
def plotActualAndPredicted(actual, predicted):
    fig, ax1 = plt.subplots(1,1)
    fig.set_size_inches(18.5, 10.5)
    ax1.plot(actual, label="actual", color="red")
    ax1.plot(predicted, label="predicted", color="green")
    fig.legend(loc="best")
    plt.show()
    
plotActualAndPredicted(actual, predicted[0])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:504: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
rmse1 = np.sqrt(((predicted-actual) ** 2).mean())
rmse1
# Out:
# 0.08365017658754487

# %% [markdown]
# # Plot de-normalized data

# %%
denormalizedActual = reverseNormalize(actual, test["Close"].values, window_len)
denormalizedPredicted = reverseNormalize(predicted, test["Close"].values, window_len)

plotActualAndPredicted(denormalizedActual, denormalizedPredicted[0])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:504: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
rmse2 = np.sqrt(((denormalizedPredicted[0]-denormalizedActual) ** 2).mean())
rmse2
# Out:
# 995.9324020837386

# %% [markdown]
# # Test model for completly random days

# %% [markdown]
# This test will use our model to predict something which cannot be predicted correctly, as the historical prices don't impact future prices - they are generated randomly.

# %%
import random

random.seed(42)
startClose = 5716.89
startVolume = 4.850614e+07

random_walk = test.copy()

newPrices = []
newVolume = []

for i in range(random_walk.shape[0]):
    startClose = startClose * (1.0 + random.randint(-10, 10) / 50.0)
    startVolume = startVolume * (1.0 + random.randint(-10, 10) / 50.0)

    newPrices.append(startClose)
    newVolume.append(startVolume)

random_walk['Close'] = newPrices
random_walk['Volume'] = newVolume

random_walk
# Out:
#                   Close        Volume
# Date
# 2017-10-16  6860.268000  4.171528e+07
# 2017-10-17  5488.214400  4.004667e+07
# 2017-10-18  5158.921536  3.764387e+07
# 2017-10-19  4539.850952  3.237373e+07
# 2017-10-20  5175.430085  2.719393e+07
# 2017-10-21  6003.498899  2.882557e+07
# 2017-10-22  4922.869097  2.306045e+07
# 2017-10-23  4135.210041  2.121562e+07
# 2017-10-24  3887.097439  2.376149e+07
# 2017-10-25  4586.774978  1.900919e+07
# 2017-10-26  5228.923475  1.748846e+07
# 2017-10-27  6274.708170  1.993684e+07
# 2017-10-28  6651.190660  1.874063e+07
# 2017-10-29  7183.285913  2.173913e+07
# 2017-10-30  6895.954476  1.739131e+07
# 2017-10-31  6206.359028  1.843478e+07
# 2017-11-01  6206.359028  1.769739e+07
# 2017-11-02  5461.595945  1.628160e+07
# 2017-11-03  5461.595945  1.400218e+07
# 2017-11-04  4587.740594  1.456226e+07
# 2017-11-05  3945.456911  1.485351e+07
# 2017-11-06  4024.366049  1.752714e+07
# 2017-11-07  3863.391407  1.437226e+07
# 2017-11-08  4172.462720  1.638437e+07
# 2017-11-09  3588.317939  1.703975e+07
# 2017-11-10  3014.187069  1.942531e+07
# 2017-11-11  2953.903327  2.331037e+07
# 2017-11-12  3485.605926  2.377658e+07
# 2017-11-13  4043.302874  2.187445e+07
# 2017-11-14  3396.374414  1.793705e+07
# ...                 ...           ...
# 2018-05-29   115.821597  1.534289e+06
# 2018-05-30   111.188733  1.564975e+06
# 2018-05-31   133.426480  1.752772e+06
# 2018-06-01   138.763539  1.998160e+06
# 2018-06-02   138.763539  1.598528e+06
# 2018-06-03   119.336644  1.534587e+06
# 2018-06-04   107.402979  1.780121e+06
# 2018-06-05   103.106860  1.459699e+06
# 2018-06-06    88.671900  1.722445e+06
# 2018-06-07    93.992214  1.756894e+06
# 2018-06-08    93.992214  1.862308e+06
# 2018-06-09   110.910812  2.085785e+06
# 2018-06-10    95.383298  2.169216e+06
# 2018-06-11   110.644626  1.995679e+06
# 2018-06-12   106.218841  1.636457e+06
# 2018-06-13   112.591971  1.309165e+06
# 2018-06-14   126.103008  1.492448e+06
# 2018-06-15   116.014767  1.522297e+06
# 2018-06-16   122.975653  1.278730e+06
# 2018-06-17   122.975653  1.508901e+06
# 2018-06-18   122.975653  1.297655e+06
# 2018-06-19   120.516140  1.453374e+06
# 2018-06-20   118.105818  1.540576e+06
# 2018-06-21   118.105818  1.602199e+06
# 2018-06-22   115.743701  1.826507e+06
# 2018-06-23   101.854457  1.680386e+06
# 2018-06-24   107.965725  1.747602e+06
# 2018-06-25    97.169152  2.062170e+06
# 2018-06-26   112.716216  2.020927e+06
# 2018-06-27   117.224865  2.303857e+06
#
# [255 rows x 2 columns]

# %%
LSTM_random_walk_inputs, LSTM_random_walk_outputs = prepareInputAndOutput(random_walk, window_len, norm_cols)

# %%
predicted_values = model.predict(LSTM_random_walk_inputs)

# %%
predicted = (np.transpose(predicted_values))

# %%
actual = LSTM_random_walk_outputs

# %%
denormalizedRandomWalkActual = reverseNormalize(actual, test["Close"].values, window_len)
denormalizedRandomWalkPredicted = reverseNormalize(predicted, test["Close"].values, window_len)

plotActualAndPredicted(denormalizedRandomWalkActual, denormalizedRandomWalkPredicted[0])
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:504: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
rmse3 = np.sqrt(((denormalizedRandomWalkPredicted[0]-denormalizedRandomWalkActual) ** 2).mean())
rmse3
# Out:
# 1131.243739831144

# %% [markdown]
# # Benchmark 1 - test using random-walk model

# %%
plotActualAndPredicted(denormalizedActual, denormalizedRandomWalkActual)
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:504: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
rmse3 = np.sqrt(((denormalizedActual-denormalizedRandomWalkActual) ** 2).mean())
rmse3
# Out:
# 3184.256588699052

# %% [markdown]
# # Benchmark 2 - test using linear regression model

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
X = train.index.values.reshape(-1, 1).astype('float64')
X
# Out:
# array([[1.4173920e+18],
#        [1.4174784e+18],
#        [1.4175648e+18],
#        ...,
#        [1.5078528e+18],
#        [1.5079392e+18],
#        [1.5080256e+18]])

# %%
X_test = test.index.values.reshape(-1, 1).astype('float64')
X_test
# Out:
# array([[1.5081120e+18],
#        [1.5081984e+18],
#        [1.5082848e+18],
#        [1.5083712e+18],
#        [1.5084576e+18],
#        [1.5085440e+18],
#        [1.5086304e+18],
#        [1.5087168e+18],
#        [1.5088032e+18],
#        [1.5088896e+18],
#        [1.5089760e+18],
#        [1.5090624e+18],
#        [1.5091488e+18],
#        [1.5092352e+18],
#        [1.5093216e+18],
#        [1.5094080e+18],
#        [1.5094944e+18],
#        [1.5095808e+18],
#        [1.5096672e+18],
#        [1.5097536e+18],
#        [1.5098400e+18],
#        [1.5099264e+18],
#        [1.5100128e+18],
#        [1.5100992e+18],
#        [1.5101856e+18],
#        [1.5102720e+18],
#        [1.5103584e+18],
#        [1.5104448e+18],
#        [1.5105312e+18],
#        [1.5106176e+18],
#        [1.5107040e+18],
#        [1.5107904e+18],
#        [1.5108768e+18],
#        [1.5109632e+18],
#        [1.5110496e+18],
#        [1.5111360e+18],
#        [1.5112224e+18],
#        [1.5113088e+18],
#        [1.5113952e+18],
#        [1.5114816e+18],
#        [1.5115680e+18],
#        [1.5116544e+18],
#        [1.5117408e+18],
#        [1.5118272e+18],
#        [1.5119136e+18],
#        [1.5120000e+18],
#        [1.5120864e+18],
#        [1.5121728e+18],
#        [1.5122592e+18],
#        [1.5123456e+18],
#        [1.5124320e+18],
#        [1.5125184e+18],
#        [1.5126048e+18],
#        [1.5126912e+18],
#        [1.5127776e+18],
#        [1.5128640e+18],
#        [1.5129504e+18],
#        [1.5130368e+18],
#        [1.5131232e+18],
#        [1.5132096e+18],
#        [1.5132960e+18],
#        [1.5133824e+18],
#        [1.5134688e+18],
#        [1.5135552e+18],
#        [1.5136416e+18],
#        [1.5137280e+18],
#        [1.5138144e+18],
#        [1.5139008e+18],
#        [1.5139872e+18],
#        [1.5140736e+18],
#        [1.5141600e+18],
#        [1.5142464e+18],
#        [1.5143328e+18],
#        [1.5144192e+18],
#        [1.5145056e+18],
#        [1.5145920e+18],
#        [1.5146784e+18],
#        [1.5147648e+18],
#        [1.5148512e+18],
#        [1.5149376e+18],
#        [1.5150240e+18],
#        [1.5151104e+18],
#        [1.5151968e+18],
#        [1.5152832e+18],
#        [1.5153696e+18],
#        [1.5154560e+18],
#        [1.5155424e+18],
#        [1.5156288e+18],
#        [1.5157152e+18],
#        [1.5158016e+18],
#        [1.5158880e+18],
#        [1.5159744e+18],
#        [1.5160608e+18],
#        [1.5161472e+18],
#        [1.5162336e+18],
#        [1.5163200e+18],
#        [1.5164064e+18],
#        [1.5164928e+18],
#        [1.5165792e+18],
#        [1.5166656e+18],
#        [1.5167520e+18],
#        [1.5168384e+18],
#        [1.5169248e+18],
#        [1.5170112e+18],
#        [1.5170976e+18],
#        [1.5171840e+18],
#        [1.5172704e+18],
#        [1.5173568e+18],
#        [1.5174432e+18],
#        [1.5175296e+18],
#        [1.5176160e+18],
#        [1.5177024e+18],
#        [1.5177888e+18],
#        [1.5178752e+18],
#        [1.5179616e+18],
#        [1.5180480e+18],
#        [1.5181344e+18],
#        [1.5182208e+18],
#        [1.5183072e+18],
#        [1.5183936e+18],
#        [1.5184800e+18],
#        [1.5185664e+18],
#        [1.5186528e+18],
#        [1.5187392e+18],
#        [1.5188256e+18],
#        [1.5189120e+18],
#        [1.5189984e+18],
#        [1.5190848e+18],
#        [1.5191712e+18],
#        [1.5192576e+18],
#        [1.5193440e+18],
#        [1.5194304e+18],
#        [1.5195168e+18],
#        [1.5196032e+18],
#        [1.5196896e+18],
#        [1.5197760e+18],
#        [1.5198624e+18],
#        [1.5199488e+18],
#        [1.5200352e+18],
#        [1.5201216e+18],
#        [1.5202080e+18],
#        [1.5202944e+18],
#        [1.5203808e+18],
#        [1.5204672e+18],
#        [1.5205536e+18],
#        [1.5206400e+18],
#        [1.5207264e+18],
#        [1.5208128e+18],
#        [1.5208992e+18],
#        [1.5209856e+18],
#        [1.5210720e+18],
#        [1.5211584e+18],
#        [1.5212448e+18],
#        [1.5213312e+18],
#        [1.5214176e+18],
#        [1.5215040e+18],
#        [1.5215904e+18],
#        [1.5216768e+18],
#        [1.5217632e+18],
#        [1.5218496e+18],
#        [1.5219360e+18],
#        [1.5220224e+18],
#        [1.5221088e+18],
#        [1.5221952e+18],
#        [1.5222816e+18],
#        [1.5223680e+18],
#        [1.5224544e+18],
#        [1.5225408e+18],
#        [1.5226272e+18],
#        [1.5227136e+18],
#        [1.5228000e+18],
#        [1.5228864e+18],
#        [1.5229728e+18],
#        [1.5230592e+18],
#        [1.5231456e+18],
#        [1.5232320e+18],
#        [1.5233184e+18],
#        [1.5234048e+18],
#        [1.5234912e+18],
#        [1.5235776e+18],
#        [1.5236640e+18],
#        [1.5237504e+18],
#        [1.5238368e+18],
#        [1.5239232e+18],
#        [1.5240096e+18],
#        [1.5240960e+18],
#        [1.5241824e+18],
#        [1.5242688e+18],
#        [1.5243552e+18],
#        [1.5244416e+18],
#        [1.5245280e+18],
#        [1.5246144e+18],
#        [1.5247008e+18],
#        [1.5247872e+18],
#        [1.5248736e+18],
#        [1.5249600e+18],
#        [1.5250464e+18],
#        [1.5251328e+18],
#        [1.5252192e+18],
#        [1.5253056e+18],
#        [1.5253920e+18],
#        [1.5254784e+18],
#        [1.5255648e+18],
#        [1.5256512e+18],
#        [1.5257376e+18],
#        [1.5258240e+18],
#        [1.5259104e+18],
#        [1.5259968e+18],
#        [1.5260832e+18],
#        [1.5261696e+18],
#        [1.5262560e+18],
#        [1.5263424e+18],
#        [1.5264288e+18],
#        [1.5265152e+18],
#        [1.5266016e+18],
#        [1.5266880e+18],
#        [1.5267744e+18],
#        [1.5268608e+18],
#        [1.5269472e+18],
#        [1.5270336e+18],
#        [1.5271200e+18],
#        [1.5272064e+18],
#        [1.5272928e+18],
#        [1.5273792e+18],
#        [1.5274656e+18],
#        [1.5275520e+18],
#        [1.5276384e+18],
#        [1.5277248e+18],
#        [1.5278112e+18],
#        [1.5278976e+18],
#        [1.5279840e+18],
#        [1.5280704e+18],
#        [1.5281568e+18],
#        [1.5282432e+18],
#        [1.5283296e+18],
#        [1.5284160e+18],
#        [1.5285024e+18],
#        [1.5285888e+18],
#        [1.5286752e+18],
#        [1.5287616e+18],
#        [1.5288480e+18],
#        [1.5289344e+18],
#        [1.5290208e+18],
#        [1.5291072e+18],
#        [1.5291936e+18],
#        [1.5292800e+18],
#        [1.5293664e+18],
#        [1.5294528e+18],
#        [1.5295392e+18],
#        [1.5296256e+18],
#        [1.5297120e+18],
#        [1.5297984e+18],
#        [1.5298848e+18],
#        [1.5299712e+18],
#        [1.5300576e+18]])

# %%
Y_test = test["Close"].values.reshape(-1, 1)
Y_test
# Out:
# array([[ 5716.89],
#        [ 5571.34],
#        [ 5587.95],
#        [ 5711.71],
#        [ 5989.1 ],
#        [ 6091.28],
#        [ 5936.92],
#        [ 5868.29],
#        [ 5508.01],
#        [ 5691.02],
#        [ 5886.73],
#        [ 5781.8 ],
#        [ 5770.01],
#        [ 6140.01],
#        [ 6124.16],
#        [ 6445.01],
#        [ 6783.69],
#        [ 7039.98],
#        [ 7170.01],
#        [ 7412.55],
#        [ 7392.  ],
#        [ 6969.76],
#        [ 7126.63],
#        [ 7467.96],
#        [ 7156.  ],
#        [ 6577.62],
#        [ 6346.7 ],
#        [ 5886.35],
#        [ 6535.87],
#        [ 6605.  ],
#        [ 7294.  ],
#        [ 7838.53],
#        [ 7714.71],
#        [ 7777.01],
#        [ 8031.82],
#        [ 8256.01],
#        [ 8109.  ],
#        [ 8250.  ],
#        [ 8031.16],
#        [ 8215.01],
#        [ 8795.5 ],
#        [ 9401.11],
#        [ 9768.71],
#        [ 9949.  ],
#        [ 9935.98],
#        [ 9903.  ],
#        [10869.84],
#        [10930.24],
#        [11290.  ],
#        [11643.98],
#        [11718.35],
#        [14090.  ],
#        [17390.01],
#        [16367.03],
#        [15309.98],
#        [15290.01],
#        [16885.76],
#        [17730.12],
#        [16689.61],
#        [16749.78],
#        [17738.67],
#        [19650.01],
#        [19378.99],
#        [19039.01],
#        [17838.73],
#        [16496.89],
#        [15758.8 ],
#        [14210.57],
#        [15075.89],
#        [14221.94],
#        [14171.98],
#        [15790.88],
#        [15367.08],
#        [14450.01],
#        [14565.05],
#        [12839.99],
#        [13863.13],
#        [13480.01],
#        [14781.51],
#        [15098.14],
#        [15144.99],
#        [16960.01],
#        [17098.99],
#        [16174.22],
#        [14993.74],
#        [14480.99],
#        [14875.18],
#        [13308.06],
#        [13820.  ],
#        [14187.95],
#        [13656.23],
#        [13590.  ],
#        [11570.01],
#        [11200.01],
#        [11305.53],
#        [11498.99],
#        [12762.8 ],
#        [11518.17],
#        [10766.7 ],
#        [10824.94],
#        [11356.79],
#        [11118.  ],
#        [11086.89],
#        [11319.  ],
#        [11536.  ],
#        [11123.01],
#        [ 9995.  ],
#        [10099.99],
#        [ 9014.23],
#        [ 8787.52],
#        [ 9240.  ],
#        [ 8167.91],
#        [ 6905.19],
#        [ 7688.46],
#        [ 7575.75],
#        [ 8218.1 ],
#        [ 8671.01],
#        [ 8547.49],
#        [ 8072.99],
#        [ 8872.28],
#        [ 8520.01],
#        [ 9472.98],
#        [10031.23],
#        [10167.49],
#        [11121.5 ],
#        [10380.04],
#        [11140.  ],
#        [11235.57],
#        [10454.27],
#        [ 9830.  ],
#        [10144.99],
#        [ 9688.62],
#        [ 9597.99],
#        [10300.  ],
#        [10566.57],
#        [10307.27],
#        [10895.92],
#        [11000.  ],
#        [11432.5 ],
#        [11469.9 ],
#        [11377.54],
#        [10700.  ],
#        [ 9925.  ],
#        [ 9304.89],
#        [ 9255.  ],
#        [ 8795.44],
#        [ 9533.88],
#        [ 9120.  ],
#        [ 9145.41],
#        [ 8207.02],
#        [ 8259.99],
#        [ 8275.  ],
#        [ 7857.6 ],
#        [ 8192.  ],
#        [ 8589.  ],
#        [ 8900.  ],
#        [ 8891.81],
#        [ 8715.09],
#        [ 8927.1 ],
#        [ 8531.34],
#        [ 8438.69],
#        [ 8179.99],
#        [ 7969.97],
#        [ 7943.  ],
#        [ 7167.09],
#        [ 6788.  ],
#        [ 6952.5 ],
#        [ 6816.05],
#        [ 7032.35],
#        [ 7392.48],
#        [ 6756.01],
#        [ 6820.  ],
#        [ 6551.  ],
#        [ 6930.03],
#        [ 7020.93],
#        [ 6693.  ],
#        [ 6790.99],
#        [ 6915.  ],
#        [ 7849.99],
#        [ 7900.  ],
#        [ 8056.01],
#        [ 8345.01],
#        [ 8011.3 ],
#        [ 7898.98],
#        [ 8151.54],
#        [ 8259.98],
#        [ 8844.12],
#        [ 8806.83],
#        [ 8855.  ],
#        [ 8929.29],
#        [ 9570.  ],
#        [ 8957.01],
#        [ 9210.  ],
#        [ 9030.  ],
#        [ 9326.62],
#        [ 9390.  ],
#        [ 9179.99],
#        [ 9042.45],
#        [ 9241.99],
#        [ 9674.99],
#        [ 9727.53],
#        [ 9788.02],
#        [ 9576.43],
#        [ 9310.01],
#        [ 9192.99],
#        [ 9310.01],
#        [ 9096.42],
#        [ 8425.48],
#        [ 8456.35],
#        [ 8747.79],
#        [ 8611.  ],
#        [ 8461.99],
#        [ 8292.22],
#        [ 8075.  ],
#        [ 8219.99],
#        [ 8221.55],
#        [ 8481.99],
#        [ 8397.  ],
#        [ 7970.38],
#        [ 7555.73],
#        [ 7580.  ],
#        [ 7399.96],
#        [ 7316.97],
#        [ 7339.99],
#        [ 7136.36],
#        [ 7423.21],
#        [ 7342.31],
#        [ 7449.99],
#        [ 7504.19],
#        [ 7629.99],
#        [ 7704.59],
#        [ 7498.66],
#        [ 7624.  ],
#        [ 7656.94],
#        [ 7656.58],
#        [ 7637.1 ],
#        [ 7597.99],
#        [ 6687.99],
#        [ 6789.98],
#        [ 6535.  ],
#        [ 6329.26],
#        [ 6621.8 ],
#        [ 6402.5 ],
#        [ 6532.52],
#        [ 6486.98],
#        [ 6704.19],
#        [ 6724.94],
#        [ 6737.68],
#        [ 6720.77],
#        [ 6081.59],
#        [ 6200.2 ],
#        [ 6146.48],
#        [ 6235.46],
#        [ 6156.57],
#        [ 6071.53]])

# %%
type(X)
# Out:
# numpy.ndarray

# %%
lr.fit(X, train["Close"].values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# -47484.432815242486
# [3.30821038e-14]

# %%
pred = lr.predict(X_test.astype('float'))

# %%
plt.scatter(X_test,Y_test,s=5, label='actual')
plt.scatter(X_test,pred,s=5, label='predicted')
plt.xlabel('Feature - X')
plt.ylabel('Target - Y')
plt.legend()
plt.show()

# %%
rmse4 = np.sqrt(((Y_test-pred) ** 2).mean())
rmse4
# Out:
# 9185.111579151624

# %%
from sklearn.model_selection import train_test_split

np.random.seed(42)
trainX, testX, trainY, testY = train_test_split(X, train["Close"].values)

# %%
pred = lr.predict(testX.astype('float'))

# %%
plt.scatter(testX,testY,s=5, label='actual')
plt.scatter(testX,pred,s=5, label='predicted')
plt.xlabel('Feature - X')
plt.ylabel('Target - Y')
plt.legend()
plt.show()

# %%
rmse5 = np.sqrt(((testY-pred) ** 2).mean())
rmse5
# Out:
# 703.5186214059062

# %% [markdown]
# # Benchmark 3 - test using moving averages

# %%
data = historical_prices

short_rolling = data.rolling(window=20).mean()
long_rolling = data.rolling(window=100).mean()

# %%
import matplotlib.dates as mdates

start_date = data.index.values[0]
end_date = data.index.values[-1]

fig, ax = plt.subplots(figsize=(16,9))

ax.plot(data.loc[start_date:end_date, :].index, data.loc[start_date:end_date, 'Close'], label='Price')
ax.plot(long_rolling.loc[start_date:end_date, :].index, long_rolling.loc[start_date:end_date, 'Close'], label = '100-days SMA')
ax.plot(short_rolling.loc[start_date:end_date, :].index, short_rolling.loc[start_date:end_date, 'Close'], label = '20-days SMA')

ax.legend(loc='best')
ax.set_ylabel('Price in $')
my_year_month_fmt = mdates.DateFormatter('%m/%y')
ax.xaxis.set_major_formatter(my_year_month_fmt)

# %%
actual = data[-testY.shape[0]:]["Close"].values.reshape(-1, 1)
pred = long_rolling[-testY.shape[0]:]["Close"].values.reshape(-1, 1)
rmse6 = np.sqrt(((actual-pred) ** 2).mean())
rmse6
# Out:
# 3758.703786460806

# %%
pred = short_rolling[-testY.shape[0]:]["Close"].values.reshape(-1, 1)
rmse7 = np.sqrt(((actual-pred) ** 2).mean())
rmse7
# Out:
# 1665.7130075038074
